# %% [markdown]
# <a href="https://colab.research.google.com/github/Rehaf1/Connect-4/blob/main/Connect4Project_phase2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scikeras
# !pip install -U scikeras scikit-learn tensorflow
# Out:
# Requirement already satisfied: scikeras in /usr/local/lib/python3.12/dist-packages (0.13.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from scikeras) (3.10.0)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from scikeras) (1.7.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (3.15.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (0.17.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (0.5.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (25.0)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.2->scikeras) (3.6.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from optree->keras>=3.2.0->scikeras) (4.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.2.0->scikeras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.2.0->scikeras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)
# Requirement already satisfied: scikeras in /usr/local/lib/python3.12/dist-packages (0.13.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.7.2)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.20.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from scikeras) (3.10.0)
# Requirement already satisfied: numpy>=1.22.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (0.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.10.5)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.9)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.2.0->scikeras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.2.0->scikeras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
import seaborn as sns
from xgboost import XGBClassifier
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.ensemble import GradientBoostingClassifier
from tensorflow.keras.layers import LeakyReLU
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow import keras
from tensorflow.keras import layers
from scikeras.wrappers import KerasClassifier
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
import sys
# !{sys.executable} -m pip install -q lightgbm
import lightgbm as lgb
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train_id = "1sZ32GzX58bA4i9-jjlqYDLTeVIBH36TO"
val_id   = "1fgYJeKUuNgVAUrZw9qWh5J5ye8VQbnlA"
test_id  = "1YEWEmUUZ1os75XCSnaJghyxXKPheK1Eo"

train_url = f"https://drive.google.com/uc?id={train_id}"
val_url   = f"https://drive.google.com/uc?id={val_id}"
test_url  = f"https://drive.google.com/uc?id={test_id}"

train_df = pd.read_csv(train_url)
val_df   = pd.read_csv(val_url)
test_df  = pd.read_csv(test_url)

# %%
#To check if i did it correctly I'll print the list
print(train_df.columns.tolist())

print("Missing values:", train_df.isnull().sum().sum())
# Out:
# ['p1', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9', 'p10', 'p11', 'p12', 'p13', 'p14', 'p15', 'p16', 'p17', 'p18', 'p19', 'p20', 'p21', 'p22', 'p23', 'p24', 'p25', 'p26', 'p27', 'p28', 'p29', 'p30', 'p31', 'p32', 'p33', 'p34', 'p35', 'p36', 'p37', 'p38', 'p39', 'p40', 'p41', 'p42', 'turn', 'label_move_col']
# Missing values: 0

# %%
#like the homework i'll seperate the x and y
x=train_df.drop("label_move_col",axis=1)
y=train_df["label_move_col"]

# %%
y.value_counts().sort_index().plot(kind='bar')
plt.xlabel("Column (Move)")
plt.ylabel("Count")
plt.title("Distribution of Target Moves")
plt.show()

# %%
#Ill begin now with the our first model Decision tree

Dt_model = DecisionTreeClassifier(
    criterion='gini',
    random_state=42,
    class_weight='balanced',
    max_depth=10,
    min_samples_split=20,
    min_samples_leaf=10,
    max_leaf_nodes=100
)
Dt_model.fit(x,y)
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_depth=10,
#                        max_leaf_nodes=100, min_samples_leaf=10,
#                        min_samples_split=20, random_state=42)

# %%
#I will validate the model now based on the validation file on kaggle

x_val=val_df.drop("label_move_col",axis=1)
y_val=val_df["label_move_col"]

# Validation

# Evaluate on training data
y_train_pred = Dt_model.predict(x)
train_acc = accuracy_score(y, y_train_pred)

# Evaluate on validation data
y_val_pred = Dt_model.predict(x_val)
val_acc = accuracy_score(y_val, y_val_pred)

print("Training Accuracy:", round(train_acc, 4))
print("Validation Accuracy:", round(val_acc, 4))


cm_dt = confusion_matrix(y_val, y_val_pred)
cm_dt_norm = cm_dt.astype('float') / cm_dt.sum(axis=1)[:, np.newaxis]

plt.figure(figsize=(10,7))
sns.heatmap(cm_dt_norm, annot=True, fmt=".2f", cmap="Blues",
            xticklabels=np.unique(y_val), yticklabels=np.unique(y_val))
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Decision Tree - Normalized Confusion Matrix")
plt.show()
# Out:
# Training Accuracy: 0.3938
# Validation Accuracy: 0.4038

# %%
# Now I try "Logistic Regression" model
log_reg_model = LogisticRegression(max_iter=1000, random_state=42)
log_reg_model.fit(x, y)
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %%
# validate the Logistic Regression model using the validation file

x_val = val_df.drop("label_move_col", axis=1)
y_val = val_df["label_move_col"]

y_val_pred = log_reg_model.predict(x_val)
# Validation

# Evaluate on training data
y_train_pred = log_reg_model.predict(x)
train_acc = accuracy_score(y, y_train_pred)

# Evaluate on validation data
y_val_pred = log_reg_model.predict(x_val)
val_acc = accuracy_score(y_val, y_val_pred)

print("Training Accuracy:", round(train_acc, 4))
print("Validation Accuracy:", round(val_acc, 4))

cm_lr = confusion_matrix(y_val, y_val_pred)
cm_lr_norm = cm_lr.astype('float') / cm_lr.sum(axis=1)[:, np.newaxis]

plt.figure(figsize=(10,7))
sns.heatmap(cm_lr_norm, annot=True, fmt=".2f", cmap="Greens",
            xticklabels=np.unique(y_val), yticklabels=np.unique(y_val))
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Logistic Regression - Normalized Confusion Matrix")
plt.show()
# Out:
# Training Accuracy: 0.3531
# Validation Accuracy: 0.3674

# %%
# Random forest


rf_model = RandomForestClassifier(
    n_estimators=500,
    random_state=42,
    class_weight="balanced",
    max_depth=15,
    min_samples_split=20,
    min_samples_leaf=10,
    max_features='sqrt',
    bootstrap=True,
    n_jobs=-1
)
rf_model.fit(x, y)


# Validation

# Evaluate on training data
y_train_pred = rf_model.predict(x)
train_acc = accuracy_score(y, y_train_pred)

# Evaluate on validation data
y_val_pred = rf_model.predict(x_val)
val_acc = accuracy_score(y_val, y_val_pred)

print("Training Accuracy:", round(train_acc, 4))
print("Validation Accuracy:", round(val_acc, 4))
# Out:
# Training Accuracy: 0.6742
# Validation Accuracy: 0.5214

# %%
#XGboost
x_val = val_df.drop("label_move_col", axis=1)
y_val = val_df["label_move_col"]

xgb_model = XGBClassifier(
    n_estimators=3000,
    learning_rate=0.02,
    max_depth=8,
    subsample=0.8,
    colsample_bytree=0.8,
    gamma=0.25,
    reg_alpha=0.1,
    reg_lambda=0.7,
    min_child_weight=2,
    objective='multi:softprob',
    random_state=42,
    num_class=7,
    eval_metric='mlogloss'
)

# Train the model
xgb_model.fit(
    x, y,
    eval_set=[(x_val, y_val)],
    verbose=False
)

# Validation

# Evaluate on training data
y_train_pred = xgb_model.predict(x)
train_acc = accuracy_score(y, y_train_pred)

# Evaluate on validation data
y_val_pred = xgb_model.predict(x_val)
val_acc = accuracy_score(y_val, y_val_pred)

print("Training Accuracy:", round(train_acc, 4))
print("Validation Accuracy:", round(val_acc, 4))

# Confusion matrix
cm_xgb = confusion_matrix(y_val, y_val_pred)
cm_xgb_norm = cm_xgb.astype('float') / cm_xgb.sum(axis=1)[:, np.newaxis]

plt.figure(figsize=(10,7))
sns.heatmap(cm_xgb_norm, annot=True, fmt=".2f", cmap="Greens",
            xticklabels=np.unique(y_val), yticklabels=np.unique(y_val))
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("XGBoost - Normalized Confusion Matrix")
plt.show()
# Out:
# Training Accuracy: 0.8988
# Validation Accuracy: 0.6412

# %%
# Select the same features used for training
used_features = [c for c in train_df.columns if c not in ["label_move_col", "id"]]
x_test = test_df[used_features]

# Generate predictions using XGBoost model
test_pred = xgb_model.predict(x_test)

# If 'id' column doesn't exist in test.csv, create it from the index
if "id" in test_df.columns:
    ids = test_df["id"]
else:
    ids = test_df.index + 1  # start IDs at 1

submission = pd.DataFrame({
    "id": ids,
    "predicted_move": test_pred.astype(int)
})

submission.to_csv("xgb1_submission.csv", index=False)
print("Saved: xgb1_submission.csv (format: id,predicted_move)")
# Out:
# Saved: xgb1_submission.csv (format: id,predicted_move)

# %%
# Classic Gradient Boosting (sklearn)
gb = GradientBoostingClassifier(
    loss="log_loss",
    learning_rate=0.09,
    n_estimators=1199,
     max_depth=4,
    min_samples_leaf=25,    # helps generalization
    subsample=0.9,          # stochastic boosting
    random_state=42,
    validation_fraction=0.15, # for early stopping
    n_iter_no_change=60        # stop when no val improvement
)
gb.fit(x, y)
# Out:
# '# Classic Gradient Boosting (sklearn)\ngb = GradientBoostingClassifier(\n    loss="log_loss",\n    learning_rate=0.09,\n    n_estimators=1199,\n     max_depth=4,\n    min_samples_leaf=25,    # helps generalization\n    subsample=0.9,          # stochastic boosting\n    random_state=42,\n    validation_fraction=0.15, # for early stopping\n    n_iter_no_change=60        # stop when no val improvement\n)\ngb.fit(x, y)'

# %%
y_val_pred = gb.predict(x_val)
# Evaluate Validation
print("Validation Accuracy:", accuracy_score(y_val, y_val_pred))
# Evaluate Training
y_train_pred = gb.predict(x)
train_acc = accuracy_score(y, y_train_pred)
print ("train",train_acc)
cm_gb=confusion_matrix(y_val,y_val_pred,normalize='true')
plt.figure(figsize=(10,7))
sns.heatmap(cm_gb, annot=True, fmt=".2f", cmap="pink",
            xticklabels=np.unique(y_val), yticklabels=np.unique(y_val))
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("GB - Normalized Confusion Matrix")
plt.show()
# Out:
# 'y_val_pred = gb.predict(x_val)\nprint("Validation Accuracy:", accuracy_score(y_val, y_val_pred))\n# Evaluate on training data\ny_train_pred = gb.predict(x)\ntrain_acc = accuracy_score(y, y_train_pred)\nprint ("train",train_acc)\ncm_gb=confusion_matrix(y_val,y_val_pred,normalize=\'true\')\nplt.figure(figsize=(10,7))\nsns.heatmap(cm_gb, annot=True, fmt=".2f", cmap="pink",\n            xticklabels=np.unique(y_val), yticklabels=np.unique(y_val))\nplt.xlabel("Predicted Label")\nplt.ylabel("True Label")\nplt.title("GB - Normalized Confusion Matrix")\nplt.show()'

# %%
#lightGBM

num_class = len(np.unique(y))

lgbm = lgb.LGBMClassifier(
    objective="multiclass",
    num_class=num_class,
    learning_rate=0.04,    # The speed for the model
    n_estimators=1200,    # More trees + early stopping
    num_leaves=55,
    max_depth=-1,         # Main control
    min_data_in_leaf=40,  # smoother leaves = less overfit
    feature_fraction=0.8,
    bagging_fraction=0.9,
    bagging_freq=1,
    reg_lambda=2.0,
    random_state=42,
    n_jobs=-1
)


lgbm.fit(
    x, y,
    eval_set=[(x_val, y_val)],
    eval_metric="multi_logloss",
    callbacks=[lgb.early_stopping(stopping_rounds=100, verbose=False)]
)

# Evaluate Validation
y_val_pred = lgbm.predict(x_val)
acc = accuracy_score(y_val, y_val_pred)
print("LightGBM Validation Accuracy:", round(acc, 4))
# Evaluate Training
y_train_pred = lgbm.predict(x)
train_acc = accuracy_score(y, y_train_pred)
print ("train",train_acc)
cm_light = confusion_matrix(y_val, y_val_pred, normalize="true")
plt.figure(figsize=(8,6))
sns.heatmap(cm_light, annot=True, fmt=".2f", cmap="pink",
            xticklabels=sorted(np.unique(y_val)),
            yticklabels=sorted(np.unique(y_val)))
plt.title("LightGBM — Normalized Confusion Matrix")
plt.xlabel("Predicted"); plt.ylabel("True"); plt.tight_layout(); plt.show()
# Out:
# '#light\n# If your label is 0..6 (7 classes). If not sure, infer it:\nnum_class = len(np.unique(y))\n\nlgbm = lgb.LGBMClassifier(\n    objective="multiclass",\n    num_class=num_class,\n    learning_rate=0.04,   # careful steps to avoid overfitting\n    n_estimators=1200,    # more trees + early stopping\n    num_leaves=55,        # try 31–127\n    max_depth=-1,         # unlimited; num_leaves is main control\n    min_data_in_leaf=40,  # smoother leaves -> less overfit\n    feature_fraction=0.8, # column subsampling\n    bagging_fraction=0.9, # row subsampling\n    bagging_freq=1,\n    reg_lambda=2.0,\n    random_state=42,\n    n_jobs=-1\n)\n\n# Train with early stopping on your validation split\nlgbm.fit(\n    x, y,\n    eval_set=[(x_val, y_val)],\n    eval_metric="multi_logloss",\n    callbacks=[lgb.early_stopping(stopping_rounds=100, verbose=False)]\n)\n\n# Evaluate\ny_val_pred = lgbm.predict(x_val)\nacc = accuracy_score(y_val, y_val_pred)\nprint("LightGBM Validation Accuracy:", round(acc, 4))\n# Evaluate on training data\ny_train_pred = lgbm.predict(x)\ntrain_acc = accuracy_score(y, y_train_pred)\nprint ("train",train_acc)\ncm_light = confusion_matrix(y_val, y_val_pred, normalize="true")\nplt.figure(figsize=(8,6))\nsns.heatmap(cm_light, annot=True, fmt=".2f", cmap="pink",\n            xticklabels=sorted(np.unique(y_val)),\n            yticklabels=sorted(np.unique(y_val)))\nplt.title("LightGBM — Normalized Confusion Matrix")\nplt.xlabel("Predicted"); plt.ylabel("True"); plt.tight_layout(); plt.show()'

# %%
# Select the same features used for training
used_features = [c for c in train_df.columns if c not in ["label_move_col", "id"]]
x_test = test_df[used_features]

# Generate predictions using LightGBM model
test_pred = lgbm.predict(x_test)

# If 'id' column doesn't exist in test.csv, create it from the index
if "id" in test_df.columns:
    ids = test_df["id"]
else:
    ids = test_df.index + 1  # start IDs at 1

submission = pd.DataFrame({
    "id": ids,
    "predicted_move": test_pred.astype(int)
})

submission.to_csv("lgbm_submission.csv", index=False)
print("Saved: lgbm_submission.csv (format: id,predicted_move)")
# Out:
# '# Select the same features used for training\nused_features = [c for c in train_df.columns if c not in ["label_move_col", "id"]]\nx_test = test_df[used_features]\n\n# Generate predictions using XGBoost model\ntest_pred = lgbm.predict(x_test)\n\n# If \'id\' column doesn\'t exist in test.csv, create it from the index\nif "id" in test_df.columns:\n    ids = test_df["id"]\nelse:\n    ids = test_df.index + 1  # start IDs at 1\n\nsubmission = pd.DataFrame({\n    "id": ids,\n    "predicted_move": test_pred.astype(int)\n})\n\nsubmission.to_csv("lgbm_submission.csv", index=False)\nprint("Saved: lgbm_submission.csv (format: id,predicted_move)")'

# %%
df = train_df.copy()
# Feature engineering
# Normalize board for current turn
for i in range(1, 43):
    df[f'p{i}'] = df[f'p{i}'] * df['turn']

# Column sums
for c in range(7):
    cols = [f'p{r}' for r in range(c + 1, 43, 7)]
    df[f'col{c+1}_sum'] = df[cols].sum(axis=1)

# Center control
center_idx = [4, 11, 18, 25, 32, 39]
df['center_control'] = df[[f'p{i}' for i in center_idx]].sum(axis=1)

# Count totals
df['my_pieces'] = (df[[f'p{i}' for i in range(1, 43)]] == 1).sum(axis=1)
df['opp_pieces'] = (df[[f'p{i}' for i in range(1, 43)]] == -1).sum(axis=1)
df['empty_cells'] = (df[[f'p{i}' for i in range(1, 43)]] == 0).sum(axis=1)

# Save new version
df.to_csv("train_engineered.csv", index=False)

x_val_processed = val_df.drop("label_move_col", axis=1)
# Feature engineering for validation data
# Normalize board for current turn
for i in range(1, 43):
    x_val_processed[f'p{i}'] = x_val_processed[f'p{i}'] * x_val_processed['turn']

# Column sums
for c in range(7):
    cols = [f'p{r}' for r in range(c + 1, 43, 7)]
    x_val_processed[f'col{c+1}_sum'] = x_val_processed[cols].sum(axis=1)

# Center control
center_idx = [4, 11, 18, 25, 32, 39]
x_val_processed['center_control'] = x_val_processed[[f'p{i}' for i in center_idx]].sum(axis=1)

# Count totals
x_val_processed['my_pieces'] = (x_val_processed[[f'p{i}' for i in range(1, 43)]] == 1).sum(axis=1)
x_val_processed['opp_pieces'] = (x_val_processed[[f'p{i}' for i in range(1, 43)]] == -1).sum(axis=1)
x_val_processed['empty_cells'] = (x_val_processed[[f'p{i}' for i in range(1, 43)]] == 0).sum(axis=1)

# %%
#neural networks model

def build_nn_model(num_classes):
    model = keras.Sequential([
        layers.Input(shape=(x.shape[1],)),
        layers.Dense(512),
        layers.LeakyReLU(negative_slope=0.05),  # 'alpha' deprecated → use negative_slope
        layers.BatchNormalization(),
        layers.Dropout(0.4),
        layers.Dense(256, activation="relu"),
        layers.BatchNormalization(),
        layers.Dropout(0.3),
        layers.Dense(128),
        layers.LeakyReLU(negative_slope=0.05),
        layers.BatchNormalization(),
        layers.Dropout(0.25),
        layers.Dense(64, activation="relu"),
        layers.BatchNormalization(),
        layers.Dropout(0.2),
        layers.Dense(num_classes, activation="softmax")
    ])

    model.compile(
        optimizer="adam",
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )
    return model

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint = ModelCheckpoint(
    'best_nn_model.keras',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

# Apply feature engineering to validation data
# Normalize board for current turn
for i in range(1, 43):
    x_val_processed[f'p{i}'] = x_val_processed[f'p{i}'] * x_val_processed['turn']

# Column sums
for c in range(7):
    cols = [f'p{r}' for r in range(c + 1, 43, 7)]
    x_val_processed[f'col{c+1}_sum'] = x_val_processed[cols].sum(axis=1)

# Center control
center_idx = [4, 11, 18, 25, 32, 39]
x_val_processed['center_control'] = x_val_processed[[f'p{i}' for i in center_idx]].sum(axis=1)

# Count totals
x_val_processed['my_pieces'] = (x_val_processed[[f'p{i}' for i in range(1, 43)]] == 1).sum(axis=1)
x_val_processed['opp_pieces'] = (x_val_processed[[f'p{i}' for i in range(1, 43)]] == -1).sum(axis=1)
x_val_processed['empty_cells'] = (x_val_processed[[f'p{i}' for i in range(1, 43)]] == 0).sum(axis=1)


num_classes = 7

nn_pipeline = Pipeline([
    ('scaler', StandardScaler()),   # scale numeric features
    ('nn', KerasClassifier(
        model=build_nn_model,
        model__num_classes=num_classes, # Pass num_classes to the model build function
        epochs=200,
        batch_size=32,
        callbacks=[keras.callbacks.EarlyStopping(patience=20, restore_best_weights=True)],
        verbose=1
    ))
])

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)
x_val_scaled = scaler.transform(x_val_processed)

num_classes = 7
nn_model_direct = build_nn_model(num_classes)


early_stopping = EarlyStopping(patience=20, restore_best_weights=True)

history = nn_model_direct.fit(
    x_scaled,
    y,
    epochs=200,
    batch_size=32,
    validation_data=(x_val_scaled, y_val),
    callbacks=[early_stopping],
    verbose=1
)

y_val_pred_probs = nn_model_direct.predict(x_val_scaled)
y_val_pred = np.argmax(y_val_pred_probs, axis=1)


print("Validation Accuracy:", accuracy_score(y_val, y_val_pred))
# Out:
# Epoch 1/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - accuracy: 0.3095 - loss: 1.9609 - val_accuracy: 0.4630 - val_loss: 1.4448
# Epoch 2/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.4107 - loss: 1.5647 - val_accuracy: 0.4839 - val_loss: 1.3895
# Epoch 3/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.4384 - loss: 1.4970 - val_accuracy: 0.5006 - val_loss: 1.3450
# Epoch 4/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.4525 - loss: 1.4583 - val_accuracy: 0.5152 - val_loss: 1.3103
# Epoch 5/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 22s 10ms/step - accuracy: 0.4666 - loss: 1.4233 - val_accuracy: 0.5267 - val_loss: 1.2757
# Epoch 6/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.4771 - loss: 1.3879 - val_accuracy: 0.5342 - val_loss: 1.2520
# Epoch 7/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.4918 - loss: 1.3655 - val_accuracy: 0.5476 - val_loss: 1.2250
# Epoch 8/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.5014 - loss: 1.3381 - val_accuracy: 0.5420 - val_loss: 1.2187
# Epoch 9/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.5018 - loss: 1.3255 - val_accuracy: 0.5538 - val_loss: 1.2004
# Epoch 10/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.5097 - loss: 1.3137 - val_accuracy: 0.5516 - val_loss: 1.1869
# Epoch 11/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.5144 - loss: 1.3055 - val_accuracy: 0.5598 - val_loss: 1.1884
# Epoch 12/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - accuracy: 0.5145 - loss: 1.2897 - val_accuracy: 0.5642 - val_loss: 1.1647
# Epoch 13/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.5231 - loss: 1.2761 - val_accuracy: 0.5644 - val_loss: 1.1617
# Epoch 14/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.5278 - loss: 1.2724 - val_accuracy: 0.5651 - val_loss: 1.1555
# Epoch 15/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.5317 - loss: 1.2536 - val_accuracy: 0.5698 - val_loss: 1.1454
# Epoch 16/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - accuracy: 0.5328 - loss: 1.2588 - val_accuracy: 0.5716 - val_loss: 1.1303
# Epoch 17/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.5323 - loss: 1.2465 - val_accuracy: 0.5731 - val_loss: 1.1289
# Epoch 18/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.5360 - loss: 1.2382 - val_accuracy: 0.5721 - val_loss: 1.1231
# Epoch 19/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.5378 - loss: 1.2305 - val_accuracy: 0.5766 - val_loss: 1.1205
# Epoch 20/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.5446 - loss: 1.2248 - val_accuracy: 0.5791 - val_loss: 1.1195
# Epoch 21/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.5426 - loss: 1.2157 - val_accuracy: 0.5792 - val_loss: 1.1061
# Epoch 22/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 22s 10ms/step - accuracy: 0.5439 - loss: 1.2158 - val_accuracy: 0.5812 - val_loss: 1.1065
# Epoch 23/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.5494 - loss: 1.2102 - val_accuracy: 0.5854 - val_loss: 1.1077
# Epoch 24/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5453 - loss: 1.2046 - val_accuracy: 0.5813 - val_loss: 1.0998
# Epoch 25/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.5518 - loss: 1.1937 - val_accuracy: 0.5848 - val_loss: 1.0948
# Epoch 26/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.5473 - loss: 1.2026 - val_accuracy: 0.5880 - val_loss: 1.0904
# Epoch 27/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.5552 - loss: 1.1913 - val_accuracy: 0.5845 - val_loss: 1.0879
# Epoch 28/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.5520 - loss: 1.1911 - val_accuracy: 0.5870 - val_loss: 1.0859
# Epoch 29/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5543 - loss: 1.1876 - val_accuracy: 0.5904 - val_loss: 1.0785
# Epoch 30/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.5558 - loss: 1.1827 - val_accuracy: 0.5911 - val_loss: 1.0754
# Epoch 31/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.5543 - loss: 1.1810 - val_accuracy: 0.5905 - val_loss: 1.0799
# Epoch 32/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.5620 - loss: 1.1661 - val_accuracy: 0.5908 - val_loss: 1.0730
# Epoch 33/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.5590 - loss: 1.1681 - val_accuracy: 0.5923 - val_loss: 1.0714
# Epoch 34/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.5626 - loss: 1.1686 - val_accuracy: 0.5910 - val_loss: 1.0713
# Epoch 35/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5695 - loss: 1.1627 - val_accuracy: 0.5935 - val_loss: 1.0685
# Epoch 36/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.5663 - loss: 1.1652 - val_accuracy: 0.5971 - val_loss: 1.0663
# Epoch 37/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.5665 - loss: 1.1609 - val_accuracy: 0.5957 - val_loss: 1.0643
# Epoch 38/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.5679 - loss: 1.1562 - val_accuracy: 0.5968 - val_loss: 1.0690
# Epoch 39/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.5617 - loss: 1.1695 - val_accuracy: 0.5950 - val_loss: 1.0612
# Epoch 40/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.5652 - loss: 1.1517 - val_accuracy: 0.5933 - val_loss: 1.0617
# Epoch 41/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - accuracy: 0.5730 - loss: 1.1445 - val_accuracy: 0.5957 - val_loss: 1.0531
# Epoch 42/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.5695 - loss: 1.1483 - val_accuracy: 0.5932 - val_loss: 1.0609
# Epoch 43/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.5697 - loss: 1.1515 - val_accuracy: 0.5904 - val_loss: 1.0600
# Epoch 44/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.5724 - loss: 1.1389 - val_accuracy: 0.5976 - val_loss: 1.0576
# Epoch 45/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.5699 - loss: 1.1434 - val_accuracy: 0.5976 - val_loss: 1.0495
# Epoch 46/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.5702 - loss: 1.1398 - val_accuracy: 0.5999 - val_loss: 1.0518
# Epoch 47/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.5709 - loss: 1.1355 - val_accuracy: 0.5969 - val_loss: 1.0508
# Epoch 48/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.5714 - loss: 1.1399 - val_accuracy: 0.5949 - val_loss: 1.0496
# Epoch 49/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - accuracy: 0.5733 - loss: 1.1380 - val_accuracy: 0.6011 - val_loss: 1.0469
# Epoch 50/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.5707 - loss: 1.1450 - val_accuracy: 0.6007 - val_loss: 1.0459
# Epoch 51/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.5773 - loss: 1.1275 - val_accuracy: 0.6052 - val_loss: 1.0434
# Epoch 52/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.5818 - loss: 1.1297 - val_accuracy: 0.6036 - val_loss: 1.0392
# Epoch 53/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.5771 - loss: 1.1213 - val_accuracy: 0.5999 - val_loss: 1.0457
# Epoch 54/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.5815 - loss: 1.1155 - val_accuracy: 0.6020 - val_loss: 1.0432
# Epoch 55/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5779 - loss: 1.1351 - val_accuracy: 0.6026 - val_loss: 1.0434
# Epoch 56/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.5795 - loss: 1.1194 - val_accuracy: 0.6018 - val_loss: 1.0403
# Epoch 57/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - accuracy: 0.5848 - loss: 1.1190 - val_accuracy: 0.6051 - val_loss: 1.0393
# Epoch 58/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.5764 - loss: 1.1176 - val_accuracy: 0.6009 - val_loss: 1.0391
# Epoch 59/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5824 - loss: 1.1076 - val_accuracy: 0.6033 - val_loss: 1.0353
# Epoch 60/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.5799 - loss: 1.1192 - val_accuracy: 0.5999 - val_loss: 1.0344
# Epoch 61/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.5850 - loss: 1.1144 - val_accuracy: 0.6044 - val_loss: 1.0315
# Epoch 62/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.5790 - loss: 1.1231 - val_accuracy: 0.6055 - val_loss: 1.0335
# Epoch 63/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 11ms/step - accuracy: 0.5817 - loss: 1.1095 - val_accuracy: 0.6039 - val_loss: 1.0319
# Epoch 64/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.5840 - loss: 1.1067 - val_accuracy: 0.6075 - val_loss: 1.0289
# Epoch 65/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.5791 - loss: 1.1098 - val_accuracy: 0.6045 - val_loss: 1.0323
# Epoch 66/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.5833 - loss: 1.1058 - val_accuracy: 0.6035 - val_loss: 1.0300
# Epoch 67/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.5841 - loss: 1.1089 - val_accuracy: 0.6048 - val_loss: 1.0292
# Epoch 68/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.5843 - loss: 1.1063 - val_accuracy: 0.6023 - val_loss: 1.0328
# Epoch 69/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.5886 - loss: 1.1037 - val_accuracy: 0.6059 - val_loss: 1.0297
# Epoch 70/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.5813 - loss: 1.1090 - val_accuracy: 0.6053 - val_loss: 1.0269
# Epoch 71/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.5919 - loss: 1.0954 - val_accuracy: 0.6053 - val_loss: 1.0287
# Epoch 72/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.5895 - loss: 1.0985 - val_accuracy: 0.6070 - val_loss: 1.0259
# Epoch 73/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.5840 - loss: 1.0982 - val_accuracy: 0.6057 - val_loss: 1.0280
# Epoch 74/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.5866 - loss: 1.1009 - val_accuracy: 0.6077 - val_loss: 1.0260
# Epoch 75/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.5901 - loss: 1.0902 - val_accuracy: 0.6077 - val_loss: 1.0253
# Epoch 76/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.5886 - loss: 1.0968 - val_accuracy: 0.6074 - val_loss: 1.0245
# Epoch 77/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5894 - loss: 1.0942 - val_accuracy: 0.6064 - val_loss: 1.0204
# Epoch 78/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.5865 - loss: 1.1005 - val_accuracy: 0.6074 - val_loss: 1.0182
# Epoch 79/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.5863 - loss: 1.0979 - val_accuracy: 0.6051 - val_loss: 1.0221
# Epoch 80/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.5920 - loss: 1.0881 - val_accuracy: 0.6072 - val_loss: 1.0227
# Epoch 81/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5869 - loss: 1.1006 - val_accuracy: 0.6062 - val_loss: 1.0262
# Epoch 82/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.5918 - loss: 1.0866 - val_accuracy: 0.6100 - val_loss: 1.0209
# Epoch 83/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.5870 - loss: 1.0951 - val_accuracy: 0.6109 - val_loss: 1.0197
# Epoch 84/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.5927 - loss: 1.0821 - val_accuracy: 0.6080 - val_loss: 1.0181
# Epoch 85/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5962 - loss: 1.0832 - val_accuracy: 0.6054 - val_loss: 1.0192
# Epoch 86/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5926 - loss: 1.0802 - val_accuracy: 0.6066 - val_loss: 1.0224
# Epoch 87/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5937 - loss: 1.0844 - val_accuracy: 0.6108 - val_loss: 1.0170
# Epoch 88/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.5871 - loss: 1.0923 - val_accuracy: 0.6095 - val_loss: 1.0185
# Epoch 89/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.5895 - loss: 1.0879 - val_accuracy: 0.6090 - val_loss: 1.0200
# Epoch 90/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.5940 - loss: 1.0857 - val_accuracy: 0.6140 - val_loss: 1.0121
# Epoch 91/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5886 - loss: 1.0887 - val_accuracy: 0.6089 - val_loss: 1.0171
# Epoch 92/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5915 - loss: 1.0866 - val_accuracy: 0.6088 - val_loss: 1.0166
# Epoch 93/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.5899 - loss: 1.0834 - val_accuracy: 0.6127 - val_loss: 1.0150
# Epoch 94/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.5990 - loss: 1.0638 - val_accuracy: 0.6119 - val_loss: 1.0126
# Epoch 95/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.5915 - loss: 1.0806 - val_accuracy: 0.6131 - val_loss: 1.0099
# Epoch 96/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5954 - loss: 1.0730 - val_accuracy: 0.6095 - val_loss: 1.0156
# Epoch 97/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.5905 - loss: 1.0805 - val_accuracy: 0.6144 - val_loss: 1.0120
# Epoch 98/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.5908 - loss: 1.0765 - val_accuracy: 0.6134 - val_loss: 1.0113
# Epoch 99/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - accuracy: 0.5972 - loss: 1.0749 - val_accuracy: 0.6132 - val_loss: 1.0107
# Epoch 100/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.5969 - loss: 1.0719 - val_accuracy: 0.6093 - val_loss: 1.0149
# Epoch 101/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.5934 - loss: 1.0779 - val_accuracy: 0.6123 - val_loss: 1.0120
# Epoch 102/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5953 - loss: 1.0806 - val_accuracy: 0.6124 - val_loss: 1.0118
# Epoch 103/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5953 - loss: 1.0752 - val_accuracy: 0.6105 - val_loss: 1.0137
# Epoch 104/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.5950 - loss: 1.0781 - val_accuracy: 0.6105 - val_loss: 1.0122
# Epoch 105/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.5954 - loss: 1.0764 - val_accuracy: 0.6126 - val_loss: 1.0127
# Epoch 106/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.6004 - loss: 1.0628 - val_accuracy: 0.6138 - val_loss: 1.0123
# Epoch 107/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6019 - loss: 1.0708 - val_accuracy: 0.6117 - val_loss: 1.0099
# Epoch 108/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.5936 - loss: 1.0703 - val_accuracy: 0.6129 - val_loss: 1.0113
# Epoch 109/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5956 - loss: 1.0782 - val_accuracy: 0.6110 - val_loss: 1.0123
# Epoch 110/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6005 - loss: 1.0590 - val_accuracy: 0.6157 - val_loss: 1.0099
# Epoch 111/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5963 - loss: 1.0666 - val_accuracy: 0.6141 - val_loss: 1.0130
# Epoch 112/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - accuracy: 0.5984 - loss: 1.0729 - val_accuracy: 0.6149 - val_loss: 1.0070
# Epoch 113/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.5959 - loss: 1.0711 - val_accuracy: 0.6126 - val_loss: 1.0089
# Epoch 114/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6017 - loss: 1.0652 - val_accuracy: 0.6139 - val_loss: 1.0074
# Epoch 115/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.6010 - loss: 1.0656 - val_accuracy: 0.6146 - val_loss: 1.0084
# Epoch 116/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.6014 - loss: 1.0580 - val_accuracy: 0.6134 - val_loss: 1.0102
# Epoch 117/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6001 - loss: 1.0613 - val_accuracy: 0.6144 - val_loss: 1.0074
# Epoch 118/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.6008 - loss: 1.0625 - val_accuracy: 0.6118 - val_loss: 1.0102
# Epoch 119/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.6018 - loss: 1.0641 - val_accuracy: 0.6168 - val_loss: 1.0099
# Epoch 120/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.5989 - loss: 1.0618 - val_accuracy: 0.6156 - val_loss: 1.0038
# Epoch 121/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.5984 - loss: 1.0604 - val_accuracy: 0.6170 - val_loss: 1.0038
# Epoch 122/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.5963 - loss: 1.0606 - val_accuracy: 0.6152 - val_loss: 1.0008
# Epoch 123/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.6046 - loss: 1.0541 - val_accuracy: 0.6164 - val_loss: 1.0054
# Epoch 124/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.5972 - loss: 1.0687 - val_accuracy: 0.6134 - val_loss: 1.0073
# Epoch 125/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.6001 - loss: 1.0674 - val_accuracy: 0.6143 - val_loss: 1.0068
# Epoch 126/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5964 - loss: 1.0617 - val_accuracy: 0.6153 - val_loss: 1.0061
# Epoch 127/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6003 - loss: 1.0570 - val_accuracy: 0.6162 - val_loss: 1.0043
# Epoch 128/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6000 - loss: 1.0609 - val_accuracy: 0.6100 - val_loss: 1.0078
# Epoch 129/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.6034 - loss: 1.0581 - val_accuracy: 0.6146 - val_loss: 1.0021
# Epoch 130/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.5995 - loss: 1.0550 - val_accuracy: 0.6138 - val_loss: 1.0051
# Epoch 131/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6007 - loss: 1.0619 - val_accuracy: 0.6162 - val_loss: 1.0040
# Epoch 132/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.6020 - loss: 1.0621 - val_accuracy: 0.6153 - val_loss: 1.0027
# Epoch 133/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.5967 - loss: 1.0658 - val_accuracy: 0.6145 - val_loss: 1.0057
# Epoch 134/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.6041 - loss: 1.0514 - val_accuracy: 0.6178 - val_loss: 1.0086
# Epoch 135/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.6031 - loss: 1.0517 - val_accuracy: 0.6156 - val_loss: 1.0115
# Epoch 136/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.6051 - loss: 1.0537 - val_accuracy: 0.6151 - val_loss: 1.0065
# Epoch 137/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6064 - loss: 1.0496 - val_accuracy: 0.6187 - val_loss: 1.0057
# Epoch 138/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.6028 - loss: 1.0475 - val_accuracy: 0.6161 - val_loss: 1.0074
# Epoch 139/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.6049 - loss: 1.0498 - val_accuracy: 0.6181 - val_loss: 1.0059
# Epoch 140/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.6021 - loss: 1.0437 - val_accuracy: 0.6163 - val_loss: 1.0038
# Epoch 141/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.6000 - loss: 1.0545 - val_accuracy: 0.6169 - val_loss: 1.0034
# Epoch 142/200
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.6031 - loss: 1.0527 - val_accuracy: 0.6163 - val_loss: 1.0033
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Validation Accuracy: 0.6151847039168369

# %%
#  Hybrid Model 2: XGBoost + Random Forest

print("\n Hybrid Model 2: XGBoost + Random Forest ===")
xgb_pred = xgb_model.predict(x_val)
xgb_probs = xgb_model.predict_proba(x_val)
rf_probs = rf_model.predict_proba(x_val)

avg_probs = (xgb_probs + rf_probs) / 2.0

hybrid2_pred = np.argmax(avg_probs, axis=1)

print("Validation Accuracy (Hybrid 2):", accuracy_score(y_val, hybrid2_pred))

xgb_train_probs = xgb_model.predict_proba(x)
rf_train_probs = rf_model.predict_proba(x)
avg_train_probs = (xgb_train_probs + rf_train_probs) / 2.0
y_train_pred = np.argmax(avg_train_probs, axis=1)

# Training accuracy
train_acc = accuracy_score(y, y_train_pred)
print("Training Accuracy (Hybrid 2):", train_acc)

cm_hybrid2 = confusion_matrix(y_val, hybrid2_pred, normalize='true')
sns.heatmap(cm_hybrid2, annot=True, fmt=".2f", cmap="Purples")
plt.title("Hybrid Model 2 (XGBoost + RF) - Normalized Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
#  Hybrid Model 2: XGBoost + Random Forest ===
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3722964497.py in <cell line: 0>()
#       2
#       3 print("\n Hybrid Model 2: XGBoost + Random Forest ===")
# ----> 4 xgb_pred = xgb_model.predict(x_val)
#       5 xgb_probs = xgb_model.predict_proba(x_val)
#       6 rf_probs = rf_model.predict_proba(x_val)
#
# NameError: name 'xgb_model' is not defined

# %%
#  Hybrid Model 3: XGBoost + Random Forest + Neural Network

print("\nHybrid Model 3: XGBoost + RF + NN ")

xgb_probs = xgb_model.predict_proba(x_val)
rf_probs = rf_model.predict_proba(x_val)
nn_probs = nn_pipeline.predict_proba(x_val)

avg_probs = (xgb_probs + rf_probs + nn_probs) / 3.0

hybrid3_pred = np.argmax(avg_probs, axis=1)
# Training accuracy
train_acc = accuracy_score(y, y_train_pred)
print("Training Accuracy (Hybrid 2):", train_acc)

print("Validation Accuracy (Hybrid 3):", accuracy_score(y_val, hybrid3_pred))

cm_hybrid3 = confusion_matrix(y_val, hybrid3_pred, normalize='true')
sns.heatmap(cm_hybrid3, annot=True, fmt=".2f", cmap="YlGnBu")
plt.title("Hybrid Model 3 (XGBoost + RF + NN) - Normalized Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
# Hybrid Model 3: XGBoost + RF + NN
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3261894906.py in <cell line: 0>()
#       3 print("\nHybrid Model 3: XGBoost + RF + NN ")
#       4
# ----> 5 xgb_probs = xgb_model.predict_proba(x_val)
#       6 rf_probs = rf_model.predict_proba(x_val)
#       7 nn_probs = nn_pipeline.predict_proba(x_val)
#
# NameError: name 'xgb_model' is not defined
